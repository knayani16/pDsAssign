# %% [markdown]
# <a href="https://colab.research.google.com/github/knayani16/pDsAssign/blob/main/datapreprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
url = '/content/gdrive/MyDrive/raw_data.csv'
raw_data = pd.read_csv(url)

# Data cleaning and preprocessing
# For example, remove duplicates
cleaned_data = raw_data.drop_duplicates()

# Convert grip strength from pounds to kilograms
cleaned_data['Grip strength (kg)'] = cleaned_data['Grip strength'] * 0.453592

# Save the cleaned data
cleaned_data.to_csv("cleaned_data.csv", index=False)

# %%
raw_data.head()
# Out:
#    Height  Weight  Age  Grip strength Frailty
# 0    65.8     112   30             30       N
# 1    71.5     136   19             31       N
# 2    69.4     153   45             29       N
# 3    68.2     142   22             28       Y
# 4    67.8     144   29             24       Y

# %%
cleaned_data.head()
# Out:
#    Height  Weight  Age  Grip strength Frailty  Grip strength (kg)
# 0    65.8     112   30             30       N           13.607760
# 1    71.5     136   19             31       N           14.061352
# 2    69.4     153   45             29       N           13.154168
# 3    68.2     142   22             28       Y           12.700576
# 4    67.8     144   29             24       Y           10.886208
